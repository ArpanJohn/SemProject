# %%
# importing all needed functions
import os
from astropy.io import fits
import numpy as np
import glob
import io
from contextlib import redirect_stdout
from Tools import tools
from Calculating_det_angles import estimate_source_angles_detectors #importing ma'ams function

# Replace 'path/to/your/file.html' with the path to your HTML file
html_file_path = r"C:\Users\arpan\Downloads\SFLAREs.html" # this
html_string = tools.extract_strings_html(html_file_path)

event_list = []
# getting only the event names
for entry in html_string:
    if 'bn' in entry:
        event_list.append(entry)

# list of events and transient type and data set name
event_list = event_list[16:21]
transient_type = 'SFLARE'
data_set_name = '21.01-5_'

# list of bin sizes
bin_list = [0.001,0.005,0.01,0.1,0.5,1,5]

# time interval around trigger
ti = [-10,100]

dir_path = tools.json_path(r'data_path.json')

event = 'bn140518709'

year = '20'+event[2:4]+"/"

# creating a temperary folder to download the data before processing into .txt files
temp_path = r"C:\Users\arpan\OneDrive\Documents\GRB\data\GRB_bn140518709"

# Finding Trigdat file
trig_string = "_trigdat_"
trig_pattern = os.path.join(temp_path,'current', f"*{trig_string}*")
trigdat_file = glob.glob(trig_pattern)

# Get the spacecraft pointing from here 
event_filename = trigdat_file[0]

# Getting the RA and DEC
with fits.open(event_filename, memmap=True) as pha_list:
    ra_obj,dec_obj = (pha_list[0].header['RA_OBJ']) ,	(pha_list[0].header['DEC_OBJ'])

trap = io.StringIO()
with redirect_stdout(trap):
    brightest_nai, bright_nais, brightest_bgo = estimate_source_angles_detectors.angle_to_grb(ra_obj,dec_obj,event_filename) # Getting the values

# Use the glob module to search for TTE files in the directory
target_string = "_tte_"
file_pattern = os.path.join(temp_path,'current', f"*{target_string}*")
NaI_detector = glob.glob(file_pattern)

print('NaI_detector used',NaI_detector[0])

# fetchinng data
with fits.open(NaI_detector[0], memmap=True) as hdul:
    energy_channel_data = hdul[1].data.copy()
    all_count_data = np.array(hdul[2].data.copy())

# getting counts accross all energy channels
counts = [float(sublist[0]) for sublist in all_count_data]

data_array = []

for i in bin_list:
    # Define the range and number of bins
    range_min = ti[0]
    range_max = ti[-1]
        
    bin_size = i

    # Create bin edges
    bin_edges = np.arange(range_min, range_max, bin_size)

    # Create the histogram using numpy.histogram
    hist, edges = np.histogram(counts, bins=bin_edges)

    data_array = data_array + list(hist)

data_array = np.array(data_array)


print(data_array)
print(data_array.shape)
# Out:
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\GRB_bn140518709\current\glg_tte_b0_bn140518709_v00.fit
# [   5    0    0 ... 8756 8574 8555]
# (144445,)

# %%
print(20000*7)
print('144445')
# Out:
# 140000
# 144445

# %%
import pandas as pd

df = pd.read_csv('all_events.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2932 entries, 0 to 2931
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   event_type   2932 non-null   object
#  1   name         2932 non-null   object
#  2   reliability  2932 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 68.8+ KB

# %%
import os
dir_path = tools.json_path(r'data_path.json')

tools.create_folder(os.path.join(dir_path, r'100_data_set'))
# Out:
# C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set' created successfully.

# %%
df['event_type'].value_counts()
# Out:
# event_type
# GRB        1250
# SFLARE      796
# TGF         668
# SGR         114
# DISTPAR     104
# Name: count, dtype: int64

# %%
# Shuffle the DataFrame
df_shuffled = df.sample(frac=1)

# %%
event_counter = {'GRB' : 0, 'SFLARE': 0 , 'TGF': 0, 'SGR':0,'DISTPAR':0}
event_limit = 100

event_type, name = [], []
for index, row in df_shuffled.iterrows():
    if event_counter[row['event_type']] < event_limit:
        event_counter[row['event_type']] += 1
        event_type.append(row['event_type'])
        name.append(row['name'])

# %%
import pandas as pd
data = {'event_type': event_type , 'name': name}
df_100 = pd.DataFrame(data)

df_100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   event_type  500 non-null    object
#  1   name        500 non-null    object
# dtypes: object(2)
# memory usage: 7.9+ KB

# %%
# importing all needed functions
import os
from astropy.io import fits
import numpy as np
import glob
import io
from contextlib import redirect_stdout
from Tools import tools
from Calculating_det_angles import estimate_source_angles_detectors #importing ma'ams function

dir_path = tools.json_path(r'data_path.json')
data_set_path = os.path.join(dir_path, r'100_data_set')
for index,row in df_100.iterrows():
    temp_path = os.path.join(dir_path, r'temp')
    tools.create_folder(temp_path)

    event = row['name']
    year = '20'+event[2:4]+"/"

    # URL of the file you want to download
    url = 'wget -q -nH --no-check-certificate --cut-dirs=7 -r -l0 -c -N -np -A "*_trigdat_*" -R "index"* -erobots=off --retr-symlinks https://heasarc.gsfc.nasa.gov/FTP/fermi/data/gbm/triggers/'+year+event+'/current/'
    tools.run_wget_download(url,temp_path)

    # Finding Trigdat file
    trig_string = "_trigdat_"
    trig_pattern = os.path.join(temp_path,'current', f"*{trig_string}*")
    trigdat_file = glob.glob(trig_pattern)

    # Get the spacecraft pointing from here 
    event_filename = trigdat_file[0]

    # Getting the RA and DEC
    with fits.open(event_filename, memmap=True) as pha_list:
        ra_obj,dec_obj = (pha_list[0].header['RA_OBJ']) ,	(pha_list[0].header['DEC_OBJ'])

    trap = io.StringIO()
    with redirect_stdout(trap):
        brightest_nai, bright_nais, brightest_bgo = estimate_source_angles_detectors.angle_to_grb(ra_obj,dec_obj,event_filename) # Getting the values

    # URL of the tte file to download
    url = 'wget -q -nH --no-check-certificate --cut-dirs=7 -r -l0 -c -N -np -A "*_tte_'+brightest_nai+'_*" -R "index"* -erobots=off --retr-symlinks https://heasarc.gsfc.nasa.gov/FTP/fermi/data/gbm/triggers/'+year+event+'/current/'
    # Construct the wget command
    tools.run_wget_download(url,os.path.join(data_set_path,row ['event_type'] + '_' + event))
# Out:
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn101104810_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn101104810_tte_n1_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn101104810
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn190320052_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn190320052_tte_n9_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn190320052
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn230413676_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn230413676_tte_n1_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn230413676
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn110228502_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn110228502_tte_n5_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn110228502
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn140103534_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn140103534_tte_n5_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn140103534
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn230711838_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn230711838_tte_n4_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn230711838
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn160411062_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn160411062_tte_n4_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn160411062
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn231231343_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn231231343_tte_n1_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn231231343
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn171129311_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn171129311_tte_na_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn171129311
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn180516229_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn180516229_tte_na_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn180516229
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn141107503_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn141107503_tte_n0_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn141107503
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn130908677_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn130908677_tte_n5_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn130908677
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn220504172_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn220504172_tte_n2_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn220504172
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn120711115_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn120711115_tte_n2_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn120711115
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn100224112_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn100224112_tte_n4_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn100224112
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn140616165_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn140616165_tte_n0_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn140616165
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn170923773_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn170923773_tte_n0_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn170923773
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn170906983_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn170906983_tte_n8_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\DISTPAR_bn170906983
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn220904222_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn220904222_tte_n3_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn220904222
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn141219218_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn141219218_tte_n9_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn141219218
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn220907587_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn220907587_tte_n2_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn220907587
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn120403857_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn120403857_tte_n9_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn120403857
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn120817168_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn120817168_tte_nb_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn120817168
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn140311159_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn140311159_tte_n4_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn140311159
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn230304624_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn230304624_tte_n8_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn230304624
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn110218537_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn110218537_tte_n4_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn110218537
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn230301167_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn230301167_tte_n3_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn230301167
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn121004211_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn121004211_tte_n4_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn121004211
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn211111667_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn211111667_tte_n3_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn211111667
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn141022696_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn141022696_tte_n1_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\DISTPAR_bn141022696
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn170116238_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn170116238_tte_n2_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn170116238
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn231106584_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn231106584_tte_n4_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn231106584
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn211001794_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn211001794_tte_n9_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn211001794
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn150727793_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn150727793_tte_n3_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn150727793
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn190509787_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn190509787_tte_na_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn190509787
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn231206235_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn231206235_tte_n5_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn231206235
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn111230819_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn111230819_tte_n0_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn111230819
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn140223495_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn140223495_tte_n7_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn140223495
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn150827996_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn150827996_tte_n7_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\DISTPAR_bn150827996
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn111022854_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn111022854_tte_n6_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn111022854
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn120618144_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn120618144_tte_nb_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\DISTPAR_bn120618144
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn090516853_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn090516853_tte_n4_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn090516853
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn160919613_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn160919613_tte_n3_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn160919613
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn130611538_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn130611538_tte_n7_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn130611538
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn160704661_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn160704661_tte_n1_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn160704661
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn100414253_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn100414253_tte_n2_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn100414253
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn200112395_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn200112395_tte_n7_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn200112395
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn231030158_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn231030158_tte_nb_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn231030158
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn230110108_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn230110108_tte_n1_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn230110108
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn171029020_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn171029020_tte_n5_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn171029020
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn221217824_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn221217824_tte_n5_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn221217824
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn230111797_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn230111797_tte_n5_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn230111797
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn180106416_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn180106416_tte_na_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn180106416
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn150127358_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn150127358_tte_n2_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn150127358
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn080717543_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn080717543_tte_n2_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn080717543
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn210722871_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn210722871_tte_n8_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn210722871
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn121108098_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn121108098_tte_n3_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn121108098
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn110214810_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn110214810_tte_n6_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn110214810
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn130717734_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn130717734_tte_nb_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn130717734
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn170220864_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn170220864_tte_n7_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn170220864
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn110309971_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn110309971_tte_n0_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn110309971
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn210701834_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn210701834_tte_nb_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn210701834
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn190101554_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn190101554_tte_n9_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn190101554
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn221225291_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn221225291_tte_nb_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn221225291
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn140118064_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn140118064_tte_n2_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn140118064
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn141122875_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn141122875_tte_n1_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn141122875
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn170908071_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn170908071_tte_n2_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\DISTPAR_bn170908071
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn090926914_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# download start
# Downloaded bn090926914_tte_nb_ to C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn090926914
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp' created successfully.
# download start
# Downloaded bn140408553_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 38
#      36 trap = io.StringIO()
#      37 with redirect_stdout(trap):
# ---> 38     brightest_nai, bright_nais, brightest_bgo = estimate_source_angles_detectors.angle_to_grb(ra_obj,dec_obj,event_filename) # Getting the values
#      40 # URL of the tte file to download
#      41 url = 'wget -q -nH --no-check-certificate --cut-dirs=7 -r -l0 -c -N -np -A "*_tte_'+brightest_nai+'_*" -R "index"* -erobots=off --retr-symlinks https://heasarc.gsfc.nasa.gov/FTP/fermi/data/gbm/triggers/'+year+event+'/current/'
#
# File c:\Users\arpan\OneDrive\Documents\GRB\SemProject\Calculating_det_angles\estimate_source_angles_detectors.py:70, in angle_to_grb(ra, dec, trigdat_file)
#      68 brightest_nai = angls_nai[res_nai[0]]
#      69 bright_nais = [angls_nai[res_nai[0]],angls_nai[res_nai[1]],angls_nai[res_nai[2]]]
# ---> 70 brightest_bgo = [angls_bgo[res_bgo[0]]]
#      71 return(brightest_nai,bright_nais,brightest_bgo)
#
# IndexError: list index out of range

# %%
print(event) #bn140408553
# Out:
# bn140408553

# %%
# importing all needed functions
import os
from astropy.io import fits
import numpy as np
import glob
import io
from contextlib import redirect_stdout
from Calculating_det_angles import estimate_source_angles_detectors #importing ma'ams function
from Tools import tools

# name of the data set
source_data_set_path = r"C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set"

# Get a list of all folders in the specified directory
folders = [str(folder) for folder in os.listdir(source_data_set_path) if os.path.isdir(os.path.join(source_data_set_path, folder))]


# list of bin sizes
bin_list = [0.001,0.005,0.01,0.1,0.5,1,5]

# time interval around trigger
ti = [-50,150]
t = ti[1] - ti[0]

# number of datapoints in a light curve
data_no = t / min(bin_list)
print(data_no)
# Out:
# 200000.0

# %%
# SFLARE_bn140213254

# %%
# importing all needed functions
import os
from astropy.io import fits
import numpy as np
import glob
import io
from contextlib import redirect_stdout
from Calculating_det_angles import estimate_source_angles_detectors #importing ma'ams function
from Tools import tools

# name of the data set
source_data_set_path = r"C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set"

# Get a list of all folders in the specified directory
folders = [str(folder) for folder in os.listdir(source_data_set_path) if os.path.isdir(os.path.join(source_data_set_path, folder))]


# list of bin sizes
bin_list = [0.001,0.005,0.01,0.1,0.5,1,5]

# time interval around trigger
ti = [-50,150]
t = ti[1] - ti[0]

# number of datapoints in a light curve
data_no = int(t / min(bin_list)) 
print('number of data point' , data_no)
 
dir_path = tools.json_path(r'data_path.json')
data_set_name = "data_set_1_proccessed"

# creating the data set folder
data_set_path = os.path.join(dir_path,data_set_name)
tools.create_folder(data_set_path)
for folder in folders:
    try:
        event_type,event = folder.split("_")
        year = '20'+event[2:4]+"/"

        # Use the glob module to search for TTE files in the directory
        target_string = "_tte_"
        file_pattern = os.path.join(source_data_set_path,folder,'current', f"*{target_string}*")
        NaI_detector = glob.glob(file_pattern)

        print('NaI_detector used',NaI_detector[0])

        # fetchinng data
        with fits.open(NaI_detector[0], memmap=True) as hdul:
            energy_channel_data = hdul[1].data.copy()
            all_count_data = np.array(hdul[2].data.copy())

        # getting counts accross all energy channels
        counts = [float(sublist[0]) for sublist in all_count_data]

        data_array = []

        for i in bin_list:
            # Define the range and number of bins
            range_min = ti[0]
            range_max = ti[1]
                
            bin_size = i

            f = data_no * i / t
        
            # Create bin edges
            bin_edges = np.arange(range_min, range_max, bin_size)

            # Create the histogram using numpy.histogram
            hist, edges = np.histogram(counts, bins=bin_edges)
            hist = list(hist)
            hist.append(sum(hist)/len(hist))
            hist = np.array(hist)
            hist = np.repeat(hist,f)
            data_array.append(hist)

        data_array = np.array(data_array)

        # Save the 2D array to a text file
        data = os.path.join(data_set_path,event_type+'_'+event)
        np.savetxt(data, data_array, fmt='%d', delimiter='\t')
        print('saved to', data)
    except Exception as e:
        print(f'error {e} in ',folder)


print('\n----------------------------------------------------------------------------\n\nevents', folders, ' in folder', data_set_path)
# Out:
# number of data point 200000
# C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed' not found.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed' created successfully.
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\DISTPAR_bn120618144\current\glg_tte_nb_bn120618144_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\DISTPAR_bn120618144
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\DISTPAR_bn141022696\current\glg_tte_n1_bn141022696_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\DISTPAR_bn141022696
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\DISTPAR_bn150827996\current\glg_tte_n7_bn150827996_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\DISTPAR_bn150827996
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\DISTPAR_bn170906983\current\glg_tte_n8_bn170906983_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\DISTPAR_bn170906983
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\DISTPAR_bn170908071\current\glg_tte_n2_bn170908071_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\DISTPAR_bn170908071
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn080717543\current\glg_tte_n2_bn080717543_v01.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn080717543
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn090516853\current\glg_tte_n4_bn090516853_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn090516853
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn090926914\current\glg_tte_nb_bn090926914_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn090926914
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn100224112\current\glg_tte_n4_bn100224112_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn100224112
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn101104810\current\glg_tte_n1_bn101104810_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn101104810
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn111022854\current\glg_tte_n6_bn111022854_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn111022854
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn111221739\current\glg_tte_n2_bn111221739_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn111221739
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn111230819\current\glg_tte_n0_bn111230819_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn111230819
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn120403857\current\glg_tte_n9_bn120403857_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn120403857
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn120711115\current\glg_tte_n2_bn120711115_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn120711115
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn120817168\current\glg_tte_nb_bn120817168_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn120817168
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn121004211\current\glg_tte_n4_bn121004211_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn121004211
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn130611538\current\glg_tte_n7_bn130611538_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn130611538
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn130704560\current\glg_tte_n4_bn130704560_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn130704560
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn130717734\current\glg_tte_nb_bn130717734_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn130717734
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn130908677\current\glg_tte_n5_bn130908677_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn130908677
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn140118064\current\glg_tte_n2_bn140118064_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn140118064
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn140223495\current\glg_tte_n7_bn140223495_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn140223495
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn140616165\current\glg_tte_n0_bn140616165_v01.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn140616165
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn141122875\current\glg_tte_n1_bn141122875_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn141122875
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn150727793\current\glg_tte_n3_bn150727793_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn150727793
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn160411062\current\glg_tte_n4_bn160411062_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn160411062
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn160919613\current\glg_tte_n3_bn160919613_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn160919613
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn170116238\current\glg_tte_n2_bn170116238_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn170116238
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn171029020\current\glg_tte_n5_bn171029020_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn171029020
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn180516229\current\glg_tte_na_bn180516229_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn180516229
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn190320052\current\glg_tte_n9_bn190320052_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn190320052
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn200112395\current\glg_tte_n7_bn200112395_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn200112395
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn210701834\current\glg_tte_nb_bn210701834_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn210701834
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn210722871\current\glg_tte_n8_bn210722871_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn210722871
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn220907587\current\glg_tte_n2_bn220907587_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn220907587
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn230111797\current\glg_tte_n5_bn230111797_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn230111797
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\GRB_bn230304624\current\glg_tte_n8_bn230304624_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\GRB_bn230304624
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn110214810\current\glg_tte_n6_bn110214810_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn110214810
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn110218537\current\glg_tte_n4_bn110218537_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn110218537
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn110228502\current\glg_tte_n5_bn110228502_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn110228502
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn110309971\current\glg_tte_n0_bn110309971_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn110309971
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn120308361\current\glg_tte_n3_bn120308361_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn120308361
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn121108098\current\glg_tte_n3_bn121108098_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn121108098
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn130217660\current\glg_tte_n5_bn130217660_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn130217660
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn131027526\current\glg_tte_n6_bn131027526_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn131027526
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn131106407\current\glg_tte_n5_bn131106407_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn131106407
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn140103534\current\glg_tte_n5_bn140103534_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn140103534
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn140213254\current\glg_tte_n3_bn140213254_v00.fit
# error buffer is too small for requested array in  SFLARE_bn140213254
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn140311159\current\glg_tte_n4_bn140311159_v00.fit
# WARNING: File may have been truncated: actual file length (168427520) is smaller than the expected size (217558080) [astropy.io.fits.file]
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn140311159
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn141107503\current\glg_tte_n0_bn141107503_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn141107503
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn160216701\current\glg_tte_n3_bn160216701_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn160216701
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn221217824\current\glg_tte_n5_bn221217824_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn221217824
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn221225291\current\glg_tte_nb_bn221225291_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn221225291
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn230110108\current\glg_tte_n1_bn230110108_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn230110108
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn230301167\current\glg_tte_n3_bn230301167_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn230301167
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn231030158\current\glg_tte_nb_bn231030158_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn231030158
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn231105605\current\glg_tte_n1_bn231105605_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn231105605
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn231106584\current\glg_tte_n4_bn231106584_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn231106584
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn231206235\current\glg_tte_n5_bn231206235_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn231206235
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\SFLARE_bn231231343\current\glg_tte_n1_bn231231343_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\SFLARE_bn231231343
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn100223288\current\glg_tte_n0_bn100223288_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn100223288
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn100414253\current\glg_tte_n2_bn100414253_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn100414253
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn110709981\current\glg_tte_n4_bn110709981_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn110709981
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn121106283\current\glg_tte_na_bn121106283_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn121106283
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn131203777\current\glg_tte_n4_bn131203777_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn131203777
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn141219218\current\glg_tte_n9_bn141219218_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn141219218
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn150127358\current\glg_tte_n2_bn150127358_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn150127358
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn160704661\current\glg_tte_n1_bn160704661_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn160704661
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn170220864\current\glg_tte_n7_bn170220864_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn170220864
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn170923773\current\glg_tte_n0_bn170923773_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn170923773
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn171129311\current\glg_tte_na_bn171129311_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn171129311
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn180106416\current\glg_tte_na_bn180106416_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn180106416
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn190101554\current\glg_tte_n9_bn190101554_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn190101554
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn190509787\current\glg_tte_na_bn190509787_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn190509787
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn211001794\current\glg_tte_n9_bn211001794_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn211001794
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn211111667\current\glg_tte_n3_bn211111667_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn211111667
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn220504172\current\glg_tte_n2_bn220504172_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn220504172
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn220904222\current\glg_tte_n3_bn220904222_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn220904222
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn230413676\current\glg_tte_n1_bn230413676_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn230413676
# NaI_detector used C:\Users\arpan\OneDrive\Documents\GRB\data\100_data_set\TGF_bn230711838\current\glg_tte_n4_bn230711838_v00.fit
# saved to C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed\TGF_bn230711838
#
# ----------------------------------------------------------------------------
#
# events ['DISTPAR_bn120618144', 'DISTPAR_bn141022696', 'DISTPAR_bn150827996', 'DISTPAR_bn170906983', 'DISTPAR_bn170908071', 'GRB_bn080717543', 'GRB_bn090516853', 'GRB_bn090926914', 'GRB_bn100224112', 'GRB_bn101104810', 'GRB_bn111022854', 'GRB_bn111221739', 'GRB_bn111230819', 'GRB_bn120403857', 'GRB_bn120711115', 'GRB_bn120817168', 'GRB_bn121004211', 'GRB_bn130611538', 'GRB_bn130704560', 'GRB_bn130717734', 'GRB_bn130908677', 'GRB_bn140118064', 'GRB_bn140223495', 'GRB_bn140616165', 'GRB_bn141122875', 'GRB_bn150727793', 'GRB_bn160411062', 'GRB_bn160919613', 'GRB_bn170116238', 'GRB_bn171029020', 'GRB_bn180516229', 'GRB_bn190320052', 'GRB_bn200112395', 'GRB_bn210701834', 'GRB_bn210722871', 'GRB_bn220907587', 'GRB_bn230111797', 'GRB_bn230304624', 'SFLARE_bn110214810', 'SFLARE_bn110218537', 'SFLARE_bn110228502', 'SFLARE_bn110309971', 'SFLARE_bn120308361', 'SFLARE_bn121108098', 'SFLARE_bn130217660', 'SFLARE_bn131027526', 'SFLARE_bn131106407', 'SFLARE_bn140103534', 'SFLARE_bn140213254', 'SFLARE_bn140311159', 'SFLARE_bn141107503', 'SFLARE_bn160216701', 'SFLARE_bn221217824', 'SFLARE_bn221225291', 'SFLARE_bn230110108', 'SFLARE_bn230301167', 'SFLARE_bn231030158', 'SFLARE_bn231105605', 'SFLARE_bn231106584', 'SFLARE_bn231206235', 'SFLARE_bn231231343', 'TGF_bn100223288', 'TGF_bn100414253', 'TGF_bn110709981', 'TGF_bn121106283', 'TGF_bn131203777', 'TGF_bn141219218', 'TGF_bn150127358', 'TGF_bn160704661', 'TGF_bn170220864', 'TGF_bn170923773', 'TGF_bn171129311', 'TGF_bn180106416', 'TGF_bn190101554', 'TGF_bn190509787', 'TGF_bn211001794', 'TGF_bn211111667', 'TGF_bn220504172', 'TGF_bn220904222', 'TGF_bn230413676', 'TGF_bn230711838']  in folder C:\Users\arpan\OneDrive\Documents\GRB\data\data_set_1_proccessed
